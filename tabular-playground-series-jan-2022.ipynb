# %%
# %%capture
# !pip install pycaret[full]

# %%
## The magic four
import pandas as pd
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt 

#garbage collection (clear up some RAM)
import gc

#pycaret
from pycaret.regression import *

#cuML
import cudf

# %matplotlib inline

# %%
#this is an aesthetic choice and just removes the many warnings that some functions and comands produce
#it helps significantly declutter the workbook
import warnings
warnings.filterwarnings('ignore')

# %%
train = cudf.read_csv('../input/tabular-playground-series-jan-2022/train.csv', index_col = 'row_id').to_pandas()
test = cudf.read_csv('../input/tabular-playground-series-jan-2022/test.csv', index_col = 'row_id').to_pandas()

# %%
# Credit to https://www.kaggle.com/ranjeetshrivastav/tps-jan-21-base-xgb

train['date'] = pd.to_datetime(train['date'])
train['year'] = train['date'].dt.year
train['month'] = train['date'].dt.month
train['day'] = train['date'].dt.day
train['dayofweek'] = train['date'].dt.dayofweek
train['dayofmonth'] = train['date'].dt.days_in_month
train['dayofyear'] = train['date'].dt.dayofyear
train['weekday'] = train['date'].dt.weekday

test['date'] = pd.to_datetime(test['date'])
test['year'] = test['date'].dt.year
test['month'] = test['date'].dt.month
test['day'] = test['date'].dt.day
test['dayofweek'] = test['date'].dt.dayofweek
test['dayofmonth'] = test['date'].dt.days_in_month
test['dayofyear'] = test['date'].dt.dayofyear
test['weekday'] = test['date'].dt.weekday

train.drop('date', axis = 1, inplace = True)
test.drop('date', axis = 1, inplace = True)

# %%
train.dtypes
# Out:
# country       object
# store         object
# product       object
# num_sold       int64
# year           int64
# month          int64
# day            int64
# dayofweek      int64
# dayofmonth     int64
# dayofyear      int64
# weekday        int64
# dtype: object

# %%
# Credit to https://www.kaggle.com/c/web-traffic-time-series-forecasting/discussion/36414
def SMAPE(y_true, y_pred):
    denominator = (y_true + np.abs(y_pred)) / 200.0
    diff = np.abs(y_true - y_pred) / denominator
    diff[denominator == 0] = 0.0
    return np.mean(diff)

# %%
reg = setup(data = train,
            target = 'num_sold',
            data_split_shuffle = False, #so that we do not use "future" observations to predict "past" observations
            create_clusters = True,
            use_gpu = True,
            silent = True,
            n_jobs = -1)
# Out:
# <style type="text/css">
# #T_b9781_row16_col1, #T_b9781_row42_col1, #T_b9781_row43_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b9781_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b9781_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b9781_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_b9781_row0_col1" class="data row0 col1" >8500</td>
#     </tr>
#     <tr>
#       <th id="T_b9781_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b9781_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_b9781_row1_col1" class="data row1 col1" >num_sold</td>
#     </tr>
#     <tr>
#       <th id="T_b9781_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b9781_row2_col0" class="data row2 col0" >Original Data</td>
#       <td id="T_b9781_row2_col1" class="data row2 col1" >(26298, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_b9781_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b9781_row3_col0" class="data row3 col0" >Missing Values</td>
#       <td id="T_b9781_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b9781_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b9781_row4_col0" class="data row4 col0" >Numeric Features</td>
#       <td id="T_b9781_row4_col1" class="data row4 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_b9781_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b9781_row5_col0" class="data row5 col0" >Categorical Features</td>
#       <td id="T_b9781_row5_col1" class="data row5 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_b9781_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b9781_row6_col0" class="data row6 col0" >Ordinal Features</td>
#       <td id="T_b9781_row6_col1" class="data row6 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b9781_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b9781_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#       <td id="T_b9781_row7_col1" class="data row7 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b9781_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b9781_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#       <td id="T_b9781_row8_col1" class="data row8 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_b9781_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b9781_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#       <td id="T_b9781_row9_col1" class="data row9 col1" >(18408, 54)</td>
#     </tr>
#     <tr>
#       <th id="T_b9781_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_b9781_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#       <td id="T_b9781_row10_col1" class="data row10 col1" >(7890, 54)</td>
#     </tr>
#     <tr>
#       <th id="T_b9781_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_b9781_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#       <td id="T_b9781_row11_col1" class="data row11 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b9781_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_b9781_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#       <td id="T_b9781_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b9781_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_b9781_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_b9781_row13_col1" class="data row13 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_b9781_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_b9781_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_b9781_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_b9781_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_b9781_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_b9781_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_b9781_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_b9781_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_b9781_row16_col1" class="data row16 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_b9781_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_b9781_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_b9781_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b9781_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_b9781_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_b9781_row18_col1" class="data row18 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_b9781_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_b9781_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_b9781_row19_col1" class="data row19 col1" >9b68</td>
#     </tr>
#     <tr>
#       <th id="T_b9781_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_b9781_row20_col0" class="data row20 col0" >Imputation Type</td>
#       <td id="T_b9781_row20_col1" class="data row20 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_b9781_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_b9781_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#       <td id="T_b9781_row21_col1" class="data row21 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_b9781_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_b9781_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#       <td id="T_b9781_row22_col1" class="data row22 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_b9781_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_b9781_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_b9781_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_b9781_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_b9781_row24_col0" class="data row24 col0" >Categorical Imputer</td>
#       <td id="T_b9781_row24_col1" class="data row24 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_b9781_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_b9781_row25_col0" class="data row25 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_b9781_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_b9781_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_b9781_row26_col0" class="data row26 col0" >Unknown Categoricals Handling</td>
#       <td id="T_b9781_row26_col1" class="data row26 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_b9781_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_b9781_row27_col0" class="data row27 col0" >Normalize</td>
#       <td id="T_b9781_row27_col1" class="data row27 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b9781_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_b9781_row28_col0" class="data row28 col0" >Normalize Method</td>
#       <td id="T_b9781_row28_col1" class="data row28 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_b9781_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_b9781_row29_col0" class="data row29 col0" >Transformation</td>
#       <td id="T_b9781_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b9781_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_b9781_row30_col0" class="data row30 col0" >Transformation Method</td>
#       <td id="T_b9781_row30_col1" class="da

# %%
models()
# Out:
#                                        Name  \
# ID
# lr                        Linear Regression
# lasso                      Lasso Regression
# ridge                      Ridge Regression
# en                              Elastic Net
# lar                  Least Angle Regression
# llar           Lasso Least Angle Regression
# omp             Orthogonal Matching Pursuit
# br                           Bayesian Ridge
# ard       Automatic Relevance Determination
# par            Passive Aggressive Regressor
# ransac              Random Sample Consensus
# tr                       TheilSen Regressor
# huber                       Huber Regressor
# kr                             Kernel Ridge
# svm               Support Vector Regression
# knn                   K Neighbors Regressor
# dt                  Decision Tree Regressor
# rf                  Random Forest Regressor
# et                    Extra Trees Regressor
# ada                      AdaBoost Regressor
# gbr             Gradient Boosting Regressor
# mlp                           MLP Regressor
# xgboost           Extreme Gradient Boosting
# lightgbm    Light Gradient Boosting Machine
# catboost                 CatBoost Regressor
# dummy                       Dummy Regressor
#
#                                                   Reference  Turbo
# ID
# lr        cuml.linear_model.linear_regression.LinearRegr...   True
# lasso                         cuml.linear_model.lasso.Lasso   True
# ridge                         cuml.linear_model.ridge.Ridge   True
# en                 cuml.linear_model.elastic_net.ElasticNet   True
# lar                  sklearn.linear_model._least_angle.Lars   True
# llar            sklearn.linear_model._least_angle.LassoLars   True
# omp       sklearn.linear_model._omp.OrthogonalMatchingPu...   True
# br                sklearn.linear_model._bayes.BayesianRidge   True
# ard               sklearn.linear_model._bayes.ARDRegression  False
# par       sklearn.linear_model._passive_aggressive.Passi...   True
# ransac         sklearn.linear_model._ransac.RANSACRegressor  False
# tr        sklearn.linear_model._theil_sen.TheilSenRegressor  False
# huber            sklearn.linear_model._huber.HuberRegressor   True
# kr                         sklearn.kernel_ridge.KernelRidge  False
# svm                                        cuml.svm.svr.SVR  False
# knn       cuml.neighbors.kneighbors_regressor.KNeighbors...   True
# dt              sklearn.tree._classes.DecisionTreeRegressor   True
# rf        cuml.ensemble.randomforestregressor.RandomFore...   True
# et             sklearn.ensemble._forest.ExtraTreesRegressor   True
# ada       sklearn.ensemble._weight_boosting.AdaBoostRegr...   True
# gbr          sklearn.ensemble._gb.GradientBoostingRegressor   True
# mlp       sklearn.neural_network._multilayer_perceptron....  False
# xgboost                        xgboost.sklearn.XGBRegressor   True
# lightgbm                     lightgbm.sklearn.LGBMRegressor   True
# catboost                    catboost.core.CatBoostRegressor   True
# dummy                          sklearn.dummy.DummyRegressor   True

# %%
add_metric('SMAPE', 'SMAPE', SMAPE, greater_is_better = False)
# Out:
# Name                                                       SMAPE
# Display Name                                               SMAPE
# Score Function                <function SMAPE at 0x7fe72c587ef0>
# Scorer               make_scorer(SMAPE, greater_is_better=False)
# Target                                                      pred
# Args                                                          {}
# Greater is Better                                          False
# Custom                                                      True
# Name: SMAPE, dtype: object

# %%
#compare_models(sort = 'MAPE')

# %%
N = 3
top = compare_models(sort = 'SMAPE', n_select = N)
# Out:
# <style type="text/css">
# #T_401d6_ th {
#   text-align: left;
# }
# #T_401d6_row0_col0, #T_401d6_row1_col0, #T_401d6_row1_col1, #T_401d6_row1_col2, #T_401d6_row1_col3, #T_401d6_row1_col4, #T_401d6_row1_col5, #T_401d6_row1_col6, #T_401d6_row1_col7, #T_401d6_row2_col0, #T_401d6_row2_col1, #T_401d6_row2_col2, #T_401d6_row2_col3, #T_401d6_row2_col4, #T_401d6_row2_col5, #T_401d6_row2_col6, #T_401d6_row2_col7, #T_401d6_row3_col0, #T_401d6_row3_col1, #T_401d6_row3_col2, #T_401d6_row3_col3, #T_401d6_row3_col4, #T_401d6_row3_col5, #T_401d6_row3_col6, #T_401d6_row3_col7, #T_401d6_row4_col0, #T_401d6_row4_col1, #T_401d6_row4_col2, #T_401d6_row4_col3, #T_401d6_row4_col4, #T_401d6_row4_col5, #T_401d6_row4_col6, #T_401d6_row4_col7, #T_401d6_row5_col0, #T_401d6_row5_col1, #T_401d6_row5_col2, #T_401d6_row5_col3, #T_401d6_row5_col4, #T_401d6_row5_col5, #T_401d6_row5_col6, #T_401d6_row5_col7, #T_401d6_row6_col0, #T_401d6_row6_col1, #T_401d6_row6_col2, #T_401d6_row6_col3, #T_401d6_row6_col4, #T_401d6_row6_col5, #T_401d6_row6_col6, #T_401d6_row6_col7, #T_401d6_row7_col0, #T_401d6_row7_col1, #T_401d6_row7_col2, #T_401d6_row7_col3, #T_401d6_row7_col4, #T_401d6_row7_col5, #T_401d6_row7_col6, #T_401d6_row7_col7, #T_401d6_row8_col0, #T_401d6_row8_col1, #T_401d6_row8_col2, #T_401d6_row8_col3, #T_401d6_row8_col4, #T_401d6_row8_col5, #T_401d6_row8_col6, #T_401d6_row8_col7, #T_401d6_row9_col0, #T_401d6_row9_col1, #T_401d6_row9_col2, #T_401d6_row9_col3, #T_401d6_row9_col4, #T_401d6_row9_col5, #T_401d6_row9_col6, #T_401d6_row9_col7, #T_401d6_row10_col0, #T_401d6_row10_col1, #T_401d6_row10_col2, #T_401d6_row10_col3, #T_401d6_row10_col4, #T_401d6_row10_col5, #T_401d6_row10_col6, #T_401d6_row10_col7, #T_401d6_row11_col0, #T_401d6_row11_col1, #T_401d6_row11_col2, #T_401d6_row11_col3, #T_401d6_row11_col4, #T_401d6_row11_col5, #T_401d6_row11_col6, #T_401d6_row11_col7, #T_401d6_row12_col0, #T_401d6_row12_col1, #T_401d6_row12_col2, #T_401d6_row12_col3, #T_401d6_row12_col4, #T_401d6_row12_col5, #T_401d6_row12_col6, #T_401d6_row12_col7, #T_401d6_row13_col0, #T_401d6_row13_col1, #T_401d6_row13_col2, #T_401d6_row13_col3, #T_401d6_row13_col4, #T_401d6_row13_col5, #T_401d6_row13_col6, #T_401d6_row13_col7, #T_401d6_row14_col0, #T_401d6_row14_col1, #T_401d6_row14_col2, #T_401d6_row14_col3, #T_401d6_row14_col4, #T_401d6_row14_col5, #T_401d6_row14_col6, #T_401d6_row14_col7, #T_401d6_row15_col0, #T_401d6_row15_col1, #T_401d6_row15_col2, #T_401d6_row15_col3, #T_401d6_row15_col4, #T_401d6_row15_col5, #T_401d6_row15_col6, #T_401d6_row15_col7, #T_401d6_row16_col0, #T_401d6_row16_col1, #T_401d6_row16_col2, #T_401d6_row16_col3, #T_401d6_row16_col4, #T_401d6_row16_col5, #T_401d6_row16_col6, #T_401d6_row16_col7, #T_401d6_row17_col0, #T_401d6_row17_col1, #T_401d6_row17_col2, #T_401d6_row17_col3, #T_401d6_row17_col4, #T_401d6_row17_col5, #T_401d6_row17_col6, #T_401d6_row17_col7, #T_401d6_row18_col0, #T_401d6_row18_col1, #T_401d6_row18_col2, #T_401d6_row18_col3, #T_401d6_row18_col4, #T_401d6_row18_col5, #T_401d6_row18_col6, #T_401d6_row18_col7, #T_401d6_row19_col0, #T_401d6_row19_col1, #T_401d6_row19_col2, #T_401d6_row19_col3, #T_401d6_row19_col4, #T_401d6_row19_col5, #T_401d6_row19_col6, #T_401d6_row19_col7 {
#   text-align: left;
# }
# #T_401d6_row0_col1, #T_401d6_row0_col2, #T_401d6_row0_col3, #T_401d6_row0_col4, #T_401d6_row0_col5, #T_401d6_row0_col6, #T_401d6_row0_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_401d6_row0_col8, #T_401d6_row1_col8, #T_401d6_row2_col8, #T_401d6_row3_col8, #T_401d6_row4_col8, #T_401d6_row5_col8, #T_401d6_row6_col8, #T_401d6_row7_col8, #T_401d6_row8_col8, #T_401d6_row9_col8, #T_401d6_row10_col8, #T_401d6_row11_col8, #T_401d6_row12_col8, #T_401d6_row13_col8, #T_401d6_row14_col8, #T_401d6_row15_col8, #T_401d6_row16_col8, #T_401d6_row18_col8, #T_401d6_row19_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_401d6_row17_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_401d6_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#       <th class="col_heading level0 col7" >SMAPE</th>
#       <th class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_401d6_level0_row0" class="row_heading level0 row0" >catboost</th>
#       <td id="T_401d6_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#       <td id="T_401d6_row0_col1" class="data row0 col1" >25.3889</td>
#       <td id="T_401d6_row0_col2" class="data row0 col2" >2216.0470</td>
#       <td id="T_401d6_row0_col3" class="data row0 col3" >44.0207</td>
#       <td id="T_401d6_row0_col4" class="data row0 col4" >0.9687</td>
#       <td id="T_401d6_row0_col5" class="data row0 col5" >0.0891</td>
#       <td id="T_401d6_row0_col6" class="data row0 col6" >0.0657</td>
#       <td id="T_401d6_row0_col7" class="data row0 col7" >6.5617</td>
#       <td id="T_401d6_row0_col8" class="data row0 col8" >2.9620</td>
#     </tr>
#     <tr>
#       <th id="T_401d6_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_401d6_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_401d6_row1_col1" class="data row1 col1" >26.9633</td>
#       <td id="T_401d6_row1_col2" class="data row1 col2" >2341.4157</td>
#       <td id="T_401d6_row1_col3" class="data row1 col3" >45.6251</td>
#       <td id="T_401d6_row1_col4" class="data row1 col4" >0.9663</td>
#       <td id="T_401d6_row1_col5" class="data row1 col5" >0.0941</td>
#       <td id="T_401d6_row1_col6" class="data row1 col6" >0.0698</td>
#       <td id="T_401d6_row1_col7" class="data row1 col7" >6.9493</td>
#       <td id="T_401d6_row1_col8" class="data row1 col8" >1.0330</td>
#     </tr>
#     <tr>
#       <th id="T_401d6_level0_row2" class="row_heading level0 row2" >xgboost</th>
#       <td id="T_401d6_row2_col0" class="data row2 col0" >Extreme Gradient Boosting</td>
#       <td id="T_401d6_row2_col1" class="data row2 col1" >26.9551</td>
#       <td id="T_401d6_row2_col2" class="data row2 col2" >2387.3140</td>
#       <td id="T_401d6_row2_col3" class="data row2 col3" >45.7763</td>
#       <td id="T_401d6_row2_col4" class="data row2 col4" >0.9661</td>
#       <td id="T_401d6_row2_col5" class="data row2 col5" >0.0938</td>
#       <td id="T_401d6_row2_col6" class="data row2 col6" >0.0701</td>
#       <td id="T_401d6_row2_col7" class="data row2 col7" >7.0162</td>
#       <td id="T_401d6_row2_col8" class="data row2 col8" >0.5470</td>
#     </tr>
#     <tr>
#       <th id="T_401d6_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_401d6_row3_col0" class="data row3 col0" >Random Forest Regressor</td>
#       <td id="T_401d6_row3_col1" class="data row3 col1" >29.1127</td>
#       <td id="T_401d6_row3_col2" class="data row3 col2" >2753.6515</td>
#       <td id="T_401d6_row3_col3" class="data row3 col3" >49.9417</td>
#       <td id="T_401d6_row3_col4" class="data row3 col4" >0.9597</td>
#       <td id="T_401d6_row3_col5" class="data row3 col5" >0.0968</td>
#       <td id="T_401d6_row3_col6" class="data row3 col6" >0.0729</td>
#       <td id="T_401d6_row3_col7" class="data row3 col7" >7.2843</td>
#       <td id="T_401d6_row3_col8" class="data row3 col8" >2.1830</td>
#     </tr>
#     <tr>
#       <th id="T_401d6_level0_row4" class="row_heading level0 row4" >et</th>
#       <td id="T_401d6_row4_col0" class="data row4 col0" >Extra Trees Regressor</td>
#       <td id="T_401d6_row4_col1" class="data row4 col1" >31.4609</td>
#       <td id="T_401d6_row4_col2" class="data row4 col2" >3196.9308</td>
#       <td id="T_401d6_row4_col3" class="data row4 col3" >54.2069</td>
#       <td id="T_401d6_row4_col4" class="data row4 col4" >0.9518</td>
#       <td

# %%
blend = blend_models(top)
predict_model(blend);
# Out:
# <style type="text/css">
# #T_c151f_row10_col0, #T_c151f_row10_col1, #T_c151f_row10_col2, #T_c151f_row10_col3, #T_c151f_row10_col4, #T_c151f_row10_col5, #T_c151f_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_c151f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#       <th class="col_heading level0 col6" >SMAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c151f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c151f_row0_col0" class="data row0 col0" >29.5474</td>
#       <td id="T_c151f_row0_col1" class="data row0 col1" >2722.4543</td>
#       <td id="T_c151f_row0_col2" class="data row0 col2" >52.1771</td>
#       <td id="T_c151f_row0_col3" class="data row0 col3" >0.9659</td>
#       <td id="T_c151f_row0_col4" class="data row0 col4" >0.0993</td>
#       <td id="T_c151f_row0_col5" class="data row0 col5" >0.0719</td>
#       <td id="T_c151f_row0_col6" class="data row0 col6" >7.1563</td>
#     </tr>
#     <tr>
#       <th id="T_c151f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c151f_row1_col0" class="data row1 col0" >29.8972</td>
#       <td id="T_c151f_row1_col1" class="data row1 col1" >2325.8880</td>
#       <td id="T_c151f_row1_col2" class="data row1 col2" >48.2275</td>
#       <td id="T_c151f_row1_col3" class="data row1 col3" >0.9664</td>
#       <td id="T_c151f_row1_col4" class="data row1 col4" >0.1062</td>
#       <td id="T_c151f_row1_col5" class="data row1 col5" >0.0835</td>
#       <td id="T_c151f_row1_col6" class="data row1 col6" >8.1095</td>
#     </tr>
#     <tr>
#       <th id="T_c151f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c151f_row2_col0" class="data row2 col0" >14.1618</td>
#       <td id="T_c151f_row2_col1" class="data row2 col1" >445.7452</td>
#       <td id="T_c151f_row2_col2" class="data row2 col2" >21.1127</td>
#       <td id="T_c151f_row2_col3" class="data row2 col3" >0.9860</td>
#       <td id="T_c151f_row2_col4" class="data row2 col4" >0.0558</td>
#       <td id="T_c151f_row2_col5" class="data row2 col5" >0.0453</td>
#       <td id="T_c151f_row2_col6" class="data row2 col6" >4.4432</td>
#     </tr>
#     <tr>
#       <th id="T_c151f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c151f_row3_col0" class="data row3 col0" >25.0028</td>
#       <td id="T_c151f_row3_col1" class="data row3 col1" >2183.9912</td>
#       <td id="T_c151f_row3_col2" class="data row3 col2" >46.7332</td>
#       <td id="T_c151f_row3_col3" class="data row3 col3" >0.9677</td>
#       <td id="T_c151f_row3_col4" class="data row3 col4" >0.0837</td>
#       <td id="T_c151f_row3_col5" class="data row3 col5" >0.0600</td>
#       <td id="T_c151f_row3_col6" class="data row3 col6" >6.0354</td>
#     </tr>
#     <tr>
#       <th id="T_c151f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c151f_row4_col0" class="data row4 col0" >36.0496</td>
#       <td id="T_c151f_row4_col1" class="data row4 col1" >4388.7771</td>
#       <td id="T_c151f_row4_col2" class="data row4 col2" >66.2478</td>
#       <td id="T_c151f_row4_col3" class="data row4 col3" >0.9471</td>
#       <td id="T_c151f_row4_col4" class="data row4 col4" >0.1236</td>
#       <td id="T_c151f_row4_col5" class="data row4 col5" >0.0849</td>
#       <td id="T_c151f_row4_col6" class="data row4 col6" >8.7208</td>
#     </tr>
#     <tr>
#       <th id="T_c151f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c151f_row5_col0" class="data row5 col0" >21.2189</td>
#       <td id="T_c151f_row5_col1" class="data row5 col1" >1235.4295</td>
#       <td id="T_c151f_row5_col2" class="data row5 col2" >35.1487</td>
#       <td id="T_c151f_row5_col3" class="data row5 col3" >0.9719</td>
#       <td id="T_c151f_row5_col4" class="data row5 col4" >0.0805</td>
#       <td id="T_c151f_row5_col5" class="data row5 col5" >0.0643</td>
#       <td id="T_c151f_row5_col6" class="data row5 col6" >6.1821</td>
#     </tr>
#     <tr>
#       <th id="T_c151f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c151f_row6_col0" class="data row6 col0" >15.5979</td>
#       <td id="T_c151f_row6_col1" class="data row6 col1" >496.0662</td>
#       <td id="T_c151f_row6_col2" class="data row6 col2" >22.2725</td>
#       <td id="T_c151f_row6_col3" class="data row6 col3" >0.9844</td>
#       <td id="T_c151f_row6_col4" class="data row6 col4" >0.0632</td>
#       <td id="T_c151f_row6_col5" class="data row6 col5" >0.0489</td>
#       <td id="T_c151f_row6_col6" class="data row6 col6" >4.9432</td>
#     </tr>
#     <tr>
#       <th id="T_c151f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c151f_row7_col0" class="data row7 col0" >30.3347</td>
#       <td id="T_c151f_row7_col1" class="data row7 col1" >3003.3035</td>
#       <td id="T_c151f_row7_col2" class="data row7 col2" >54.8024</td>
#       <td id="T_c151f_row7_col3" class="data row7 col3" >0.9662</td>
#       <td id="T_c151f_row7_col4" class="data row7 col4" >0.0869</td>
#       <td id="T_c151f_row7_col5" class="data row7 col5" >0.0637</td>
#       <td id="T_c151f_row7_col6" class="data row7 col6" >6.4121</td>
#     </tr>
#     <tr>
#       <th id="T_c151f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c151f_row8_col0" class="data row8 col0" >34.6730</td>
#       <td id="T_c151f_row8_col1" class="data row8 col1" >4035.0386</td>
#       <td id="T_c151f_row8_col2" class="data row8 col2" >63.5220</td>
#       <td id="T_c151f_row8_col3" class="data row8 col3" >0.9544</td>
#       <td id="T_c151f_row8_col4" class="data row8 col4" >0.1114</td>
#       <td id="T_c151f_row8_col5" class="data row8 col5" >0.0765</td>
#       <td id="T_c151f_row8_col6" class="data row8 col6" >7.9234</td>
#     </tr>
#     <tr>
#       <th id="T_c151f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c151f_row9_col0" class="data row9 col0" >16.1384</td>
#       <td id="T_c151f_row9_col1" class="data row9 col1" >524.2737</td>
#       <td id="T_c151f_row9_col2" class="data row9 col2" >22.8970</td>
#       <td id="T_c151f_row9_col3" class="data row9 col3" >0.9864</td>
#       <td id="T_c151f_row9_col4" class="data row9 col4" >0.0595</td>
#       <td id="T_c151f_row9_col5" class="data row9 col5" >0.0483</td>
#       <td id="T_c151f_row9_col6" class="data row9 col6" >4.7815</td>
#     </tr>
#     <tr>
#       <th id="T_c151f_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_c151f_row10_col0" class="data row10 col0" >25.2622</td>
#       <td id="T_c151f_row10_col1" class="data row10 col1" >2136.0967</td>
#       <td id="T_c151f_row10_col2" class="data row10 col2" >43.3141</td>
#       <td id="T_c151f_row10_col3" class="data row10 col3" >0.9696</td>
#       <td id="T_c151f_row10_col4" class="data row10 col4" >0.0870</td>
#       <td id="T_c151f_row10_col5" class="data row10 col5" >0.0647</td>
#       <td id="T_c151f_row10_col6" class="data row10 col6" >6.4707</td>
#     </tr>
#     <tr>
#       <th id="T_c151f_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_c151f_row11_col0" class="data row11 col0" >7.6602</td>
#       <td id="T_c151f_row11_col1" class="data row11 col1" >1370.0690</td>
#       <td id="T_c151f_row11_col2" class="data row11 col2" >16.1241</td>
#       <td id="T_c151f_row11_col3" class="data row11 col3" >0.0124</td>
#       <td id="T_c151f_row11_col4" class="data row11 col4" >0.0219</td>
#       <td id="T_c151f_row11_col5" class="data row11 col5" >0.0137</td>
#       <td id="T_c151f_row11_col6" class="data row11 col6" >1.4108</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_eee14_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#       <th class="col_heading level0 col7" >SMAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eee14_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_eee14_row0_col0" class="data row0 col0" >Voting Regressor</td>
#       <td id="T_eee14_row0_col1" class="data row0 col1" >42.8648</td>
#       <td id="T_eee14_row0_col2" class="data row0 col2" >5360.1064</td>
#       <td id="T_eee14_row0_col3" class="data row0 col3" >73.2127</td>
#       <td id="T_eee14_row0_col4" class="data row0 col4" >0.9367</td>
#       <td id="T_eee14_row0_col5" class="data row0 col5" >0.1216</td>
#       <td id="T_eee14_row0_col6" class="data row0 col6" >0.0905</td>
#       <td id="T_eee14_row0_col7" class="data row0 col7" >9.6024</td>
#     </tr>
#   </tbody>
# </table>

# %%
final_blend = finalize_model(blend)
predict_model(final_blend);
# Out:
# <style type="text/css">
# </style>
# <table id="T_5c6f1_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#       <th class="col_heading level0 col7" >SMAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5c6f1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5c6f1_row0_col0" class="data row0 col0" >Voting Regressor</td>
#       <td id="T_5c6f1_row0_col1" class="data row0 col1" >20.5943</td>
#       <td id="T_5c6f1_row0_col2" class="data row0 col2" >1070.8094</td>
#       <td id="T_5c6f1_row0_col3" class="data row0 col3" >32.7232</td>
#       <td id="T_5c6f1_row0_col4" class="data row0 col4" >0.9874</td>
#       <td id="T_5c6f1_row0_col5" class="data row0 col5" >0.0597</td>
#       <td id="T_5c6f1_row0_col6" class="data row0 col6" >0.0473</td>
#       <td id="T_5c6f1_row0_col7" class="data row0 col7" >4.7927</td>
#     </tr>
#   </tbody>
# </table>

# %%
#N = 3: 4.7978
#N = 4: 4.5288
#N = 5: 3.6129
#N = 6: 3.9910

# %%
#tuned_top = [tune_model(i, optimize = 'MAPE', choose_better = True) for i in top]

# %%
#tuned_blend = blend_models(tuned_top)
#predict_model(tuned_blend);

# %%
#final_tuned_blend = finalize_model(tuned_blend)
#predict_model(final_tuned_blend);

# %%
gc.collect()
unseen_predictions_blend = predict_model(final_blend, data=test)
unseen_predictions_blend.head()
# Out:
#         country       store         product  year  month  day  dayofweek  \
# row_id
# 26298   Finland  KaggleMart      Kaggle Mug  2019      1    1          1
# 26299   Finland  KaggleMart      Kaggle Hat  2019      1    1          1
# 26300   Finland  KaggleMart  Kaggle Sticker  2019      1    1          1
# 26301   Finland  KaggleRama      Kaggle Mug  2019      1    1          1
# 26302   Finland  KaggleRama      Kaggle Hat  2019      1    1          1
#
#         dayofmonth  dayofyear  weekday        Label
# row_id
# 26298           31          1        1   386.537208
# 26299           31          1        1   590.709176
# 26300           31          1        1   175.871997
# 26301           31          1        1   669.206591
# 26302           31          1        1  1002.992452

# %%
gc.collect()

assert(len(test.index)==len(unseen_predictions_blend))

sub = pd.DataFrame(list(zip(test.index, unseen_predictions_blend.Label)),columns = ['row_id', 'num_sold'])

sub.to_csv('submission.csv', index = False)

print(sub)
# Out:
#       row_id     num_sold
# 0      26298   386.537208
# 1      26299   590.709176
# 2      26300   175.871997
# 3      26301   669.206591
# 4      26302  1002.992452
# ...      ...          ...
# 6565   32863   839.922878
# 6566   32864   231.508540
# 6567   32865   987.710762
# 6568   32866  1502.964192
# 6569   32867   424.943613
#
# [6570 rows x 2 columns]
